# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
dataBase = client["demo1_mongoDB"]

# %%
collection = dataBase['Products']

# %%
d = {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'}

# %%
rec = collection.insert_one(d)

# %%
all_record = collection.find()

# %%
d = {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment',
     'price': 17790}

rec = collection.insert_one(d)

all_record = collection.find()

# %%
for idx, record in enumerate(all_record):
     print(f"{idx}: {record}")
# Out:
# 0: {'_id': ObjectId('63d007ab96c47ab1fc79a075'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# 1: {'_id': ObjectId('63d007af96c47ab1fc79a076'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment', 'price': 17790}

# %%
new_database = client["demo2"]
new_collection = new_database["my_products"]

# %%
doc1 = {
    "name":"Laptop",
    'price': 119990
}

new_collection.insert_one(doc1)

# %%
result_data = new_collection.find()


for key, value in enumerate(result_data):
    print(key, value)
# Out:
# 0 {'_id': ObjectId('63d007b696c47ab1fc79a077'), 'name': 'Laptop', 'price': 119990}

# %%
doc2 = [
            {
            "name":"Samsung",
            'price': 89900,
            "description":"This is an andriod device",
            "manufacturer_details":{
                "name":"Samsung South Korea",
                "address":"South Korea"
            }
        },
            {
                "name":"LAVA",
                'price': 19900,
                "description":"This is an medium range andriod device",
                "manufacturer_details":{
                    "name":"LAVA",
                    "address":"INDIA",
                    "license_no":"IN34521"
                }
            }
    
]
new_collection.insert_many(doc2)

# %%
new_database.list_collection_names()
# Out:
# ['my_products']

# %%
result_data = new_collection.find()


for key, value in enumerate(result_data):
    print(key, value)
# Out:
# 0 {'_id': ObjectId('63d007b696c47ab1fc79a077'), 'name': 'Laptop', 'price': 119990}
# 1 {'_id': ObjectId('63d007bb96c47ab1fc79a078'), 'name': 'Samsung', 'price': 89900, 'description': 'This is an andriod device', 'manufacturer_details': {'name': 'Samsung South Korea', 'address': 'South Korea'}}
# 2 {'_id': ObjectId('63d007bb96c47ab1fc79a079'), 'name': 'LAVA', 'price': 19900, 'description': 'This is an medium range andriod device', 'manufacturer_details': {'name': 'LAVA', 'address': 'INDIA', 'license_no': 'IN34521'}}

# %%
from bson.objectid import ObjectId
print(new_collection.find_one({"_id" : ObjectId("638c708d2622ad6cc6466491")}))
# Out:
# None

# %%
new_collection.delete_one({"price" :89900})

# %%
result_data = new_collection.find()


for key, value in enumerate(result_data):
    print(key, value)
# Out:
# 0 {'_id': ObjectId('63d007b696c47ab1fc79a077'), 'name': 'Laptop', 'price': 119990}
# 1 {'_id': ObjectId('63d007bb96c47ab1fc79a079'), 'name': 'LAVA', 'price': 19900, 'description': 'This is an medium range andriod device', 'manufacturer_details': {'name': 'LAVA', 'address': 'INDIA', 'license_no': 'IN34521'}}

# %%
new_collection.update_many({},{'$set':{"marker":"toBeDeleted"}})

# %%
new_collection.delete_many({"marker":"toBeDeleted"})

# %%
result_data = new_collection.find()


for key, value in enumerate(result_data):
    print(key, value)

# %%
result_data = new_collection.find_one({'price': {'$gt' : 20000}})
print(result_data)
# Out:
# None

# %%
d = [
  {
    "name": "Max Schwarzmueller",
    "age": 29
  },
  {
    "name": "Manu Lorenz",
    "age": 30
  },
  {
    "name": "Chris Hayton",
    "age": 35
  },
  {
    "name": "Sandeep Kumar",
    "age": 28
  },
  {
    "name": "Maria Jones",
    "age": 30
  },
  {
    "name": "Alexandra Maier",
    "age": 27
  },
  {
    "name": "Dr. Phil Evans",
    "age": 47
  },
  {
    "name": "Sandra Brugge",
    "age": 33
  },
  {
    "name": "Elisabeth Mayr",
    "age": 29
  },
  {
    "name": "Frank Cube",
    "age": 41
  },
  {
    "name": "Karandeep Alun",
    "age": 48
  },
  {
    "name": "Michaela Drayer",
    "age": 39
  },
  {
    "name": "Bernd Hoftstadt",
    "age": 22
  },
  {
    "name": "Scott Tolib",
    "age": 44
  },
  {
    "name": "Freddy Melver",
    "age": 41
  },
  {
    "name": "Alexis Bohed",
    "age": 35
  },
  {
    "name": "Melanie Palace",
    "age": 27
  },
  {
    "name": "Armin Glutch",
    "age": 35
  },
  {
    "name": "Klaus Arber",
    "age": 53
  },
  {
    "name": "Albert Twostone",
    "age": 68
  },
  {
    "name": "Gordon Black",
    "age": 38
  }
]

new_collection = new_database['passenger_details']

new_collection.insert_many(d)

result = new_collection.find({},{'age':1,'_id':0})

for i in result:
  print(i)
# Out:
# {'age': 29}
# {'age': 30}
# {'age': 35}
# {'age': 28}
# {'age': 30}
# {'age': 27}
# {'age': 47}
# {'age': 33}
# {'age': 29}
# {'age': 41}
# {'age': 48}
# {'age': 39}
# {'age': 22}
# {'age': 44}
# {'age': 41}
# {'age': 35}
# {'age': 27}
# {'age': 35}
# {'age': 53}
# {'age': 68}
# {'age': 38}

# %%
import pandas as pd

# %%
import json

df = pd.read_csv("https://raw.githubusercontent.com/vigneshk/Admission-Dataset/master/Admission.csv")
data_json = json.loads(df.to_json(orient='records'))
rec = collection.insert_many(data_json)
print(rec)

# %%
for data in collection.find():
    print(data)
# Out:
# {'_id': ObjectId('63d007ab96c47ab1fc79a075'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('63d007af96c47ab1fc79a076'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment', 'price': 17790}
# {'_id': ObjectId('63d0095496c47ab1fc79a08f'), 'Serial No.': 1, 'GRE Score': 337, 'TOEFL Score': 118, 'University Rating': 4, 'SOP': 4.5, 'LOR ': 4.5, 'CGPA': 9.65, 'Research': 1, 'Chance of Admit ': 0.92}
# {'_id': ObjectId('63d0095496c47ab1fc79a090'), 'Serial No.': 2, 'GRE Score': 324, 'TOEFL Score': 107, 'University Rating': 4, 'SOP': 4.0, 'LOR ': 4.5, 'CGPA': 8.87, 'Research': 1, 'Chance of Admit ': 0.76}
# {'_id': ObjectId('63d0095496c47ab1fc79a091'), 'Serial No.': 3, 'GRE Score': 316, 'TOEFL Score': 104, 'University Rating': 3, 'SOP': 3.0, 'LOR ': 3.5, 'CGPA': 8.0, 'Research': 1, 'Chance of Admit ': 0.72}
# ...

# %%
dataBase = client["iNeuron1"]
collection = dataBase['GRE']

df = pd.read_csv("https://raw.githubusercontent.com/vigneshk/Admission-Dataset/master/Admission.csv")

data_json = json.loads(df.to_json(orient='records'))
rec = collection.insert_many(data_json)
for data in collection.find():
    print(data)
# Out:
# {'_id': ObjectId('63d0096796c47ab1fc79a21f'), 'Serial No.': 1, 'GRE Score': 337, 'TOEFL Score': 118, 'University Rating': 4, 'SOP': 4.5, 'LOR ': 4.5, 'CGPA': 9.65, 'Research': 1, 'Chance of Admit ': 0.92}
# {'_id': ObjectId('63d0096796c47ab1fc79a220'), 'Serial No.': 2, 'GRE Score': 324, 'TOEFL Score': 107, 'University Rating': 4, 'SOP': 4.0, 'LOR ': 4.5, 'CGPA': 8.87, 'Research': 1, 'Chance of Admit ': 0.76}
# {'_id': ObjectId('63d0096796c47ab1fc79a221'), 'Serial No.': 3, 'GRE Score': 316, 'TOEFL Score': 104, 'University Rating': 3, 'SOP': 3.0, 'LOR ': 3.5, 'CGPA': 8.0, 'Research': 1, 'Chance of Admit ': 0.72}
# {'_id': ObjectId('63d0096796c47ab1fc79a222'), 'Serial No.': 4, 'GRE Score': 322, 'TOEFL Score': 110, 'University Rating': 3, 'SOP': 3.5, 'LOR ': 2.5, 'CGPA': 8.67, 'Research': 1, 'Chance of Admit ': 0.8}
# ...
